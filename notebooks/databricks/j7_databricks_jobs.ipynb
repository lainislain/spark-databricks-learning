# %% [markdown]
# # S2 J7 - Databricks Jobs (Workflow)
#
# Goal: create and run a Databricks Job from a notebook task.

# %%
# Optional job parameter (useful for manual and scheduled runs)
dbutils.widgets.text("run_label", "manual", "Run Label")
run_label = dbutils.widgets.get("run_label")
print("run_label:", run_label)

# %%
print("Spark version:", spark.version)
df = spark.range(0, 1000)
print("count:", df.count())

# %%
spark.sql("SELECT current_timestamp() AS run_ts, current_user() AS user_name").show(truncate=False)
