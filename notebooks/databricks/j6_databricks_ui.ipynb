# %% [markdown]
# # S2 J6 - Databricks UI (Clusters + Notebooks)
#
# Goal: get autonomous with Databricks basics.

# %%
# Verify Spark session and runtime
print("Spark version:", spark.version)
print("Current database:", spark.catalog.currentDatabase())

# %%
# Basic DataFrame test
df = spark.range(0, 10)
print("Row count:", df.count())
df.show()

# %%
# Simple SQL test in Databricks
spark.sql("SELECT current_timestamp() AS run_ts, current_user() AS user_name").show(truncate=False)
