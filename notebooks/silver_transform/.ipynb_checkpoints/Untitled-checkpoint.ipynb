# %%
import pyspark
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("example-transform")
    .getOrCreate()
)
# Out:
# JAVA_HOME is not set
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[6], line 7
#       1 import pyspark
#       2 from pyspark.sql import SparkSession
#       4 spark = (
#       5     SparkSession.builder
#       6     .appName("example-transform")
# ----> 7     .getOrCreate()
#       8 )
#
# File ~/spark_env/lib/python3.12/site-packages/pyspark/sql/session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File ~/spark_env/lib/python3.12/site-packages/pyspark/core/context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File ~/spark_env/lib/python3.12/site-packages/pyspark/core/context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File ~/spark_env/lib/python3.12/site-packages/pyspark/core/context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File ~/spark_env/lib/python3.12/site-packages/pyspark/java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.

# %%
from pyspark.sql import functions as F, types as T

data_path = "../../data/example.csv"

df = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv(data_path)
)

# Inline lookup table: plan -> monthly_fee, tier
lookup = spark.createDataFrame(
    [
        ("Free", 0, "low"),
        ("Basic", 29, "mid"),
        ("Pro", 79, "mid"),
        ("Enterprise", 199, "high"),
    ],
    schema=["plan", "monthly_fee", "tier"]
)

# Transformations: filter, join, derived columns
result = (
    df
    .filter((F.col("is_active") == True) & (F.col("spend") > 0))
    .join(lookup, on="plan", how="left")
    .withColumn("signup_date", F.to_date("signup_date"))
    .withColumn("spend_per_month", F.round(F.col("spend") / F.lit(12), 2))
    .withColumn("high_value", F.col("spend") >= 500)
    .select(
        "name", "age", "city", "signup_date",
        "plan", "tier", "monthly_fee", "spend",
        "spend_per_month", "high_value"
    )
)

result.show(truncate=False)
result.printSchema()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       1 from pyspark.sql import functions as F, types as T
#       3 data_path = "../../data/example.csv"
#       5 df = (
# ----> 6     spark.read
#       7     .option("header", True)
#       8     .option("inferSchema", True)
#       9     .csv(data_path)
#      10 )
#      12 # Inline lookup table: plan -> monthly_fee, tier
#      13 lookup = spark.createDataFrame(
#      14     [
#      15         ("Free", 0, "low"),
#    (...)     20     schema=["plan", "monthly_fee", "tier"]
#      21 )
#
# NameError: name 'spark' is not defined
